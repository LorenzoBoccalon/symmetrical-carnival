# %% [markdown]
# # Scraper: Beer Recipes
#
# python web scaper for [Brewer's Friend](https://www.brewersfriend.com/search/)

# %%
from bs4 import BeautifulSoup
from requests.structures import CaseInsensitiveDict
import aiohttp
import asyncio
import csv
import json
import nest_asyncio
import pandas as pd
import re
import requests
import time


nest_asyncio.apply()

# %%
MAX_PAGE_NUMBER = 1
url = "https://www.brewersfriend.com/search/index.php"


def soupy(response_text: str) -> BeautifulSoup:
    return BeautifulSoup(response_text, "html.parser")


def get_last_page_number(response_text: str) -> int:
    soup = soupy(response_text)
    last_page = soup.select_one("#navrow > td.right > ul > li:nth-child(1) > a")
    last_page = last_page.text.strip()
    last_page = last_page.replace(",", "")
    last_page = last_page.rsplit(" ", 1)[-1]
    last_page = int(last_page)
    return last_page


def get_html_response(page_number: int = 1) -> requests.Response:
    assert 1 <= page_number <= MAX_PAGE_NUMBER, "Page number out of bounds!"
    headers = CaseInsensitiveDict()
    headers["Content-Type"] = "application/x-www-form-urlencoded"
    headers[
        "User-Agent"
    ] = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36"
    data = f"units=metric&page={page_number}"
    response = requests.post(url, headers=headers, data=data)
    assert response.status_code == 200, "Response not OK!"
    return response


def parse_links(response_text: str) -> pd.DataFrame:
    links = []
    soup = soupy(response_text)
    for link in soup.find_all("a", {"class": "recipetitle", "href": True}):
        links.append(link["href"])
    ids = [re.search(r"view/(\d+)/", link).group(1) for link in links]
    return pd.DataFrame({"links": links, "ids": ids})


def parse_metadata(response_text: str) -> pd.DataFrame:
    result = []
    for df in pd.read_html(response_text):
        # ugly af but it works
        if len(df) != 4:
            continue
        data = df.loc[1].tolist() + df.loc[2].tolist() + df.iloc[[0, 3], 0].tolist()
        curr = dict()
        for entry in data:
            k, v = entry.split(":", 1)
            curr[k] = v.strip()
        result.append(curr)
    return pd.DataFrame(result)


response = get_html_response()
MAX_PAGE_NUMBER = get_last_page_number(response.text)
MAX_PAGE_NUMBER
# Out:
# 5668

# %% [markdown]
# # TODO
# - chiamate parallele asincrone

# %%
response = get_html_response(100)

# %%
links = parse_links(response.text)

print("links found:", len(links), ", last 3:")
print(links[-3:])
# Out:
# links found: 20 , last 3:
#                                                 links     ids
# 17  /homebrew/recipe/view/256343/black-apricot-fud...  256343
# 18  /homebrew/recipe/view/103985/imperial-coffee-s...  103985
# 19       /homebrew/recipe/view/491642/blueberry-wheat  491642

# %%
parse_metadata(response.text)
# Out:
#       Boil  Size Boil Time Boil Gravity Efficiency Mash Thickness  \
# 0      40 Litres        75        1.035         50            N/A
# 1      27 Litres        60        1.031         72              4
# 2    31.5 Litres        60        1.048         70              3
# 3      25 Litres        60        1.049         72            2.5
# 4    1125 Litres        80        1.044         80              3
# 5      29 Litres        70        1.048         74              3
# 6      83 Litres        60         1.04         75           4.35
# 7      28 Litres        60        1.058         70            N/A
# 8    28.5 Litres        60        1.035         70            2.5
# 9      25 Litres        60         1.05         75            N/A
# 10     28 Litres        60        1.097         78              3
# 11     11 Litres        90         19.6         35            N/A
# 12     26 Litres        60        1.042         68            N/A
# 13     27 Litres        60        1.047       72.5            2.5
# 14     23 Litres        70           25         70            N/A
# 15     15 Litres        60        1.045         70              3
# 16     73 Litres        60          5.3         65              3
# 17  11.18 Litres        60           22         65            N/A
# 18     26 Litres        60        1.065         40            N/A
# 19     28 Litres        60        1.037         70            N/A
#
#         Sugar  Scale Brew  Method Pitch Rate Primary  Temp Priming Method  \
# 0   Specific Gravity         BIAB        N/A        22 ° C            N/A
# 1   Specific Gravity    All Grain       0.35        19 ° C            N/A
# 2   Specific Gravity    All Grain        N/A        22 ° C            N/A
# 3   Specific Gravity    All Grain        N/A        21 ° C            N/A
# 4   Specific Gravity    All Grain       1.75        11 ° C            N/A
# 5   Specific Gravity    All Grain       0.75        20 ° C            N/A
# 6   Specific Gravity    All Grain        N/A        10 ° C            N/A
# 7   Specific Gravity    All Grain        N/A        18 ° C            N/A
# 8   Specific Gravity    All Grain       0.75        18 ° C            N/A
# 9   Specific Gravity         BIAB       0.75        18 ° C            co2
# 10  Specific Gravity    All Grain        1.0           N/A            N/A
# 11             Plato      Extract        N/A           N/A            N/A
# 12  Specific Gravity         BIAB       0.75        18 ° C            N/A
# 13  Specific Gravity    All Grain        0.5        20 ° C            N/A
# 14             Plato    All Grain        N/A           N/A            N/A
# 15  Specific Gravity    All Grain        N/A        13 ° C            N/A
# 16             Plato    All Grain       0.35           N/A            co2
# 17             Plato    All Grain        N/A        23 ° C            N/A
# 18  Specific Gravity         BIAB       0.35        21 ° C            N/A
# 19  Specific Gravity    All Grain       0.75        19 ° C            N/A
#
#    Priming Amount       Creation  Date                  Author  \
# 0             N/A   5/17/2018 11:49 AM                 Nick Mc
# 1             N/A  11/10/2018 10:44 AM                    BAAS
# 2             N/A    3/30/2016 9:41 AM                Rompetom
# 3             N/A   12/10/2013 1:31 AM             walrusdunne
# 4             N/A    8/20/2015 8:21 PM            4 Mile Brews
# 5             N/A   7/22/2019 11:03 AM                   pughj
# 6             N/A     9/7/2016 1:55 PM                 Strasak
# 7             N/A   10/7/2017 12:58 PM             Bakke Brygg
# 8             N/A    1/22/2018 5:09 AM
# 9             N/A   12/31/2015 2:34 AM                   AnteK
# 10            N/A    1/15/2017 9:58 AM  ampi1679@hotmail.co.uk
# 11            N/A    5/28/2014 7:48 AM                  bebebe
# 12            N/A    1/28/2015 4:07 PM                 FagnerZ
# 13            N/A     7/4/2018 9:56 AM                JohnnyAH
# 14            N/A    5/10/2015 8:21 AM                 Nanoist
# 15            N/A   11/2/2016 10:21 AM                   murat
# 16       2.07 bar    7/25/2019 8:50 PM              Black Hops
# 17            N/A    6/28/2015 9:34 PM                  Joiski
# 18            N/A     2/2/2014 1:33 AM                 NeiloGD
# 19            N/A    5/12/2017 9:29 PM       Homebrew Fanatics
#
#                                                 Notes
# 0   Setup done in garage, under cover, no wind, am...
# 1
# 2
# 3   Won IPA category 3rd place in UK Homebrew Comp...
# 4
# 5
# 6   Final Gravity: 1016 SRM (real): 22 storage: 1-...
# 7
# 8   http://beersmithrecipes.com/viewrecipe/1328260...
# 9   BIAB method for Braumeister 20l, efficiency 75...
# 10  added 1.5 pack of brandy soaked fruit 2oz x me...
# 11
# 12
# 13
# 14
# 15
# 16
# 17  4L Nachguss. 19 Plato nach Hopfenkochen (20°C)...
# 18
# 19

# %% [markdown]
# https://docs.scrapy.org/en/latest/intro/tutorial.html
# https://docs.scrapy.org/en/latest/topics/dynamic-content.html
# https://reqbin.com/

# %% [markdown]
# **manca aggiustare le funzioni per scaricare il beerxml**

# %%
def get_beerxml_url(html) -> str:    
    for a in html.find_all("a", href=True):
        href = a["href"]
        if "/beerxml" in href:
            return href


# build BeerXml from id
url = "https://www.brewersfriend.com/homebrew/recipe/downloadbeerxml/{id}".format(id=ids[0])
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
response = requests.get(url, headers=headers)
soup = soupy(response.text)

print(soup.title.text, get_beerxml_url(soup))
# Out:
# Avg. Perfect Northeast IPA (NEIPA) - Beer Recipe | Brewer's Friend https://www.brewersfriend.com/homebrew/recipe/beerxml1.0/363082

# %%
url = "https://www.brewersfriend.com/homebrew/recipe/beerxml1.0/363082"
response = requests.get(url, headers=headers)

import xml.dom.minidom

dom = xml.dom.minidom.parseString(response.text)
pretty_xml_as_string = dom.toprettyxml()

print(pretty_xml_as_string.split("\n")[:10])
# Out:
# ['<?xml version="1.0" ?>', '<RECIPES>', '\t', ' ', '\t<RECIPE>', '\t\t', '  ', '\t\t<NAME>Avg. Perfect Northeast IPA (NEIPA)</NAME>', '\t\t', '  ']
